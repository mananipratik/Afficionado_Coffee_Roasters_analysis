# %% [markdown]
# ### import libarys

# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### read data

# %%
df = pd.read_csv("../data/Afficionado Coffee Roasters.csv")

# %%
df.head()
# Out:
#    transaction_id  year transaction_time  transaction_qty  store_id  \
# 0               1  2025          7:06:11                2         5
# 1               2  2025          7:08:56                2         5
# 2               3  2025          7:14:04                2         5
# 3               4  2025          7:20:24                1         5
# 4               5  2025          7:22:41                2         5
#
#     store_location  product_id  unit_price    product_category  \
# 0  Lower Manhattan          32         3.0              Coffee
# 1  Lower Manhattan          57         3.1                 Tea
# 2  Lower Manhattan          59         4.5  Drinking Chocolate
# 3  Lower Manhattan          22         2.0              Coffee
# 4  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# 1        Brewed Chai tea     Spicy Eye Opener Chai Lg
# ...

# %%
df.describe()
# Out:
#        transaction_id      year  transaction_qty       store_id  \
# count   149116.000000  149116.0    149116.000000  149116.000000
# mean     74737.371872    2025.0         1.438276       5.342063
# std      43153.600016       0.0         0.542509       2.074241
# min          1.000000    2025.0         1.000000       3.000000
# 25%      37335.750000    2025.0         1.000000       3.000000
# 50%      74727.500000    2025.0         1.000000       5.000000
# 75%     112094.250000    2025.0         2.000000       8.000000
# max     149456.000000    2025.0         8.000000       8.000000
#
#           product_id     unit_price
# count  149116.000000  149116.000000
# mean       47.918607       3.382219
# std        17.930020       2.658723
# min         1.000000       0.800000
# 25%        33.000000       2.500000
# 50%        47.000000       3.000000
# 75%        60.000000       3.750000
# max        87.000000      45.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   year              149116 non-null  int64
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 12.5+ MB

# %%
df.size
# Out:
# 1640276

# %%
df.sample()
# Out:
#         transaction_id  year transaction_time  transaction_qty  store_id  \
# 112242          112500  2025         10:11:14                1         8
#
#         store_location  product_id  unit_price product_category  \
# 112242  Hell's Kitchen          40        3.75           Coffee
#
#             product_type product_detail
# 112242  Barista Espresso     Cappuccino
