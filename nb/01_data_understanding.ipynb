# %% [markdown]
# ### import libarys

# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### read data

# %%
df1 = Path("../data/Afficionado Coffee Roasters.csv")
